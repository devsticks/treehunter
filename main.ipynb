# %%
# %run utils.ipynb
# %run image_reg.ipynb
#%run optical_flow.ipynb

# Inputs
tifFilename = "Images/orthomosaic_visible.tif"
droneFilename = "Images/drone_1_small.jpg"
markerLoc = (18.825515, -32.328862) #lonlat

# Read images
imTif = cv2.imread(tifFilename, cv2.IMREAD_COLOR)
imDrone = cv2.imread(droneFilename, cv2.IMREAD_COLOR)

# Get pixels corresponding to marker in tif
markerPixel = pixelAtLocation(tifFilename, markerLoc)

# Display input images. Overlay marker on tif.
fig = plt.figure(figsize=(20,20))
fig.add_subplot(1,2,1)
plt.imshow(imTif)
plt.scatter(markerPixel[0], markerPixel[1], s=200, c='red', marker='o')
fig.add_subplot(1,2,2)
plt.imshow(imDrone)
plt.show()

# Pre-process images and markerPixel (they must be transformed too...)

# Align


# Display aligned image over reference

#
# Out:
# (2205.820639178157, 5059.67073763907)
# Coords are on the image
